# %%
import openparse

basic_doc_path = "pdf/pp_yolo.pdf"
parser = openparse.DocumentParser()
parsed_basic_doc = parser.parse(basic_doc_path)
pdf = openparse.Pdf(basic_doc_path)
pdf.display_with_bboxes(
    parsed_basic_doc.nodes
)

# %%
import re
def _clean(text):
    text = re.sub(r'\- \n', '- ', text)
    return text

ts = '''Figure 1. Comparison of the proposed PP-YOLO and other state- 
of-the-art object detectors. PP-YOLO runs faster than YOLOv4 
and improves mAP from 43.5% to 45.2%.'''

_clean(ts)
# Out:
# 'Figure 1. Comparison of the proposed PP-YOLO and other state- of-the-art object detectors. PP-YOLO runs faster than YOLOv4 \nand improves mAP from 43.5% to 45.2%.'
